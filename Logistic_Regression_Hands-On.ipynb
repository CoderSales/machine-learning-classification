# %% [markdown]
# ## Pima Indians Diabetes Case study
# Diabetes is one of the most frequent diseases worldwide and the number of diabetic patients is growing over the years. The main cause of diabetes remains unknown, yet scientists believe that both genetic factors and environmental lifestyle play a major role in diabetes.
#
# Individuals with diabetes face a risk of developing some secondary health issues such as heart diseases and nerve damage. Thus, early detection and treatment of diabetes can prevent complications and assist in reducing the risk of severe health problems.
# Even though it's incurable, it can be managed by treatment and medication.
#
# Researchers at the Bio-Solutions lab want to get better understanding of this disease among women and are planning to use machine learning models that will help them to identify patients who are at risk of diabetes.
#
# We will use logistic regression to model the "Pima Indians Diabetes" data set. In particular, all patients here are females at least 21 years old of Pima Indian heritage. This model will predict which people are likely to develop diabetes.

# %% [markdown]
# ## Data Description:
#
# * Pregnancies: Number of times pregnant
# * Glucose: Plasma glucose concentration over 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skinfold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * Pedigree: Diabetes pedigree function - A function that scores likelihood of diabetes based on family history.
# * Age: Age in years
# * Class: Class variable (0: the person is not diabetic or 1: the person is diabetic)

# %%
# install
# https://discourse.jupyter.org/t/python-in-terminal-finds-module-jupyter-notebook-does-not/2262/7
# **!**pip install module name
# !pip install could install to wrong env use % instead
# %pip install jupyter notebook
# %pip install matplotlib
# %pip install pandas
# %pip install seaborn
# %pip install numpy
# %pip install scipy
# %pip install statsmodels
# %pip install -U scikit-learn
# %pip install ipykernel
# !pip install nb-black
# %pip install nb-black
# Out:
# Requirement already satisfied: jupyter in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.0.0)
# Requirement already satisfied: notebook in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (6.5.2)
# Requirement already satisfied: ipykernel in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter) (6.19.2)
# Requirement already satisfied: ipywidgets in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter) (8.0.4)
# Requirement already satisfied: nbconvert in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter) (7.2.9)
# Requirement already satisfied: jupyter-console in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter) (6.4.4)
# Requirement already satisfied: qtconsole in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter) (5.4.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from notebook) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from notebook) (0.16.0)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from notebook) (1.5.6)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from notebook) (0.5.1)
# Requirement already satisfied: ipython-genutils in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from notebook) (0.2.0)
# Requirement already satisfied: nbformat in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from notebook) (5.7.3)
# Requirement already satisfied: tornado>=6.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from notebook) (6.2)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from notebook) (5.1.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from notebook) (24.0.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from notebook) (1.8.0)
# Requirement already satisfied: traitlets>=4.2.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from notebook) (5.7.1)
# Requirement already satisfied: jinja2 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from notebook) (3.1.2)
# Requirement already satisfied: argon2-cffi in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from notebook) (21.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from notebook) (7.4.8)
# Requirement already satisfied: entrypoints in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-client>=5.3.4->notebook) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-client>=5.3.4->notebook) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-core>=4.6.1->notebook) (305)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-core>=4.6.1->notebook) (2.6.0)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbclassic>=0.4.7->notebook) (2.2.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbclassic>=0.4.7->notebook) (0.2.2)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbconvert->jupyter) (2.13.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbconvert->jupyter) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbconvert->jupyter) (4.11.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbconvert->jupyter) (0.7.2)
# Requirement already satisfied: defusedxml in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: bleach in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbconvert->jupyter) (6.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbconvert->jupyter) (2.1.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbconvert->jupyter) (2.0.4)
# Requirement already satisfied: packaging in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbconvert->jupyter) (22.0)
# Requirement already satisfied: fastjsonschema in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbformat->notebook) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nbformat->notebook) (4.17.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from terminado>=0.8.3->notebook) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from argon2-cffi->notebook) (21.2.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel->jupyter) (0.1.2)
# Requirement already satisfied: psutil in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel->jupyter) (5.9.4)
# Requirement already satisfied: debugpy>=1.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel->jupyter) (1.6.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel->jupyter) (8.7.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets->jupyter) (3.0.5)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipywidgets->jupyter) (4.0.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-console->jupyter) (3.0.36)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from qtconsole->jupyter) (2.3.0)
# Requirement already satisfied: backcall in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.2)
# Requirement already satisfied: colorama in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: decorator in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.18.2)
# Requirement already satisfied: pickleshare in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=2.6->nbformat->notebook) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=2.6->nbformat->notebook) (0.19.3)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (3.6.2)
# Requirement already satisfied: websocket-client in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (1.5.0)
# Requirement already satisfied: jupyter-events>=0.4.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (0.4.4)
# Requirement already satisfied: wcwidth in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.2->jupyter-client>=5.3.4->notebook) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bleach->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (3.4)
# Requirement already satisfied: pycparser in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (0.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (2.0.4)
# Requirement already satisfied: rfc3339-validator in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (0.1.4)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (6.0)
# Requirement already satisfied: pure-eval in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (1.2.0)
# Requirement already satisfied: uri-template in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=2.6->nbformat->notebook) (1.2.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=2.6->nbformat->notebook) (1.12)
# Requirement already satisfied: isoduration in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=2.6->nbformat->notebook) (20.11.0)
# Requirement already satisfied: fqdn in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=2.6->nbformat->notebook) (1.5.1)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=2.6->nbformat->notebook) (2.3)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from isoduration->jsonschema>=2.6->nbformat->notebook) (1.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.6.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: numpy>=1.19 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.24.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: six>=1.5 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas) (1.24.1)
# Requirement already satisfied: six>=1.5 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.12.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from seaborn) (3.6.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from seaborn) (1.24.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (22.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.24.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.10.0)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scipy) (1.24.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: statsmodels in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.13.5)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from statsmodels) (1.24.1)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: scipy>=1.3 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from statsmodels) (1.10.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from statsmodels) (1.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from statsmodels) (22.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.25->statsmodels) (2022.7.1)
# Requirement already satisfied: six in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn) (1.24.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipykernel in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (6.19.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (1.6.4)
# Requirement already satisfied: tornado>=6.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (6.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (24.0.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (8.7.0)
# Requirement already satisfied: nest-asyncio in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (1.5.6)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (5.7.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: packaging in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (22.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (7.4.8)
# Requirement already satisfied: psutil in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel) (5.9.4)
# Requirement already satisfied: pickleshare in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel) (2.13.0)
# Requirement already satisfied: decorator in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: colorama in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: stack-data in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.6.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.18.2)
# Requirement already satisfied: backcall in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-client>=6.1.12->ipykernel) (5.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-client>=6.1.12->ipykernel) (0.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: pywin32>=1.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel) (305)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel) (2.6.0)
# Requirement already satisfied: wcwidth in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=7.23.1->ipykernel) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: pure-eval in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nb-black in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.0.7)
# Requirement already satisfied: ipython in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nb-black) (8.7.0)
# Requirement already satisfied: black>='19.3' in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nb-black) (22.12.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from black>='19.3'->nb-black) (8.1.3)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from black>='19.3'->nb-black) (0.10.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from black>='19.3'->nb-black) (2.6.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from black>='19.3'->nb-black) (0.4.3)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from black>='19.3'->nb-black) (2.0.1)
# Requirement already satisfied: matplotlib-inline in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->nb-black) (0.1.6)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->nb-black) (2.13.0)
# Requirement already satisfied: decorator in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->nb-black) (5.1.1)
# Requirement already satisfied: backcall in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->nb-black) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->nb-black) (0.6.2)
# Requirement already satisfied: colorama in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->nb-black) (0.4.6)
# Requirement already satisfied: jedi>=0.16 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->nb-black) (0.18.2)
# Requirement already satisfied: traitlets>=5 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->nb-black) (5.7.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->nb-black) (3.0.36)
# Requirement already satisfied: pickleshare in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->nb-black) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jedi>=0.16->ipython->nb-black) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython->nb-black) (0.2.5)
# Requirement already satisfied: pure-eval in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython->nb-black) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython->nb-black) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython->nb-black) (2.2.1)
# Requirement already satisfied: six in c:\users\steph\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from asttokens>=2.1.0->stack-data->ipython->nb-black) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import necessary libraries

# %%
# To filter the warnings
import warnings

warnings.filterwarnings("ignore")

# Libraries to help with reading and manipulating data
import pandas as pd
import numpy as np

# libaries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Library to split data
from sklearn.model_selection import train_test_split


# To build linear model for statistical analysis and prediction
import statsmodels.stats.api as sms
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
from statsmodels.tools.tools import add_constant

# To get diferent metric scores
from sklearn import metrics
from sklearn.metrics import accuracy_score, roc_curve, confusion_matrix, roc_auc_score


# this will help in making the Python code more structured automatically (good coding practice)
# %load_ext nb_black

# %% [markdown]
# ### Read the dataset

# %%
data = pd.read_csv("pima-indians-diabetes.csv")

# %% [markdown]
# ### View the first and last 5 rows of the dataset

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    Pedigree  Age  Class
# 0     0.627   50      1
# 1     0.351   31      0
# 2     0.672   32      1
# 3     0.167   21      0
# 4     2.288   33      1

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      Pedigree  Age  Class
# 763     0.171   63      0
# 764     0.340   27      0
# 765     0.245   30      0
# 766     0.349   47      1
# 767     0.315   23      0

# %% [markdown]
# ### Understand the shape of the dataset

# %%
data.shape
# Out:
# (768, 9)

# %% [markdown]
# * There are 768 observations and 9 columns in the dataset

# %% [markdown]
# ### Checking for null values in the data

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# * We don't have missing values in the data.

# %% [markdown]
# #### Distribution of variables in the data

# %%
sns.set_style("darkgrid")
data.hist(figsize=(15, 10))
plt.show()

# %% [markdown]
# * We can see that Glucose, BloodPressure, SkinThickness, Insulin, BMI have obervations with 0 values, which is not possible. These are data entry errors and we should fix it.
# * We will replace 0 values in all the columns except Pregnancies and Class with the NaN (this will help us deal with the missing values elegantly)
# * We will impute missing (NaN) values with the mean.

# %%
# defining columns where we need to replace 0 with NaN
cols = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "Pedigree"]

# %%
# replacing 0 with NaN
data[cols] = data[cols].replace(0, np.nan)

# %%
# let's check missing values in the data again
data.isna().sum()
# Out:
# Pregnancies        0
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# Pedigree           0
# Age                0
# Class              0
# dtype: int64

# %%
# Let's impute missing values using mean value
data[cols] = data[cols].fillna(data[cols].mean())

# %%
# let's check missing values in the data again
data.isna().sum()
# Out:
# Pregnancies      0
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# Pedigree         0
# Age              0
# Class            0
# dtype: int64

# %% [markdown]
# * We have imputed all the data entry errors with the mean values.

# %% [markdown]
# ### Bivariate Analysis

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(data.corr(), annot=True, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# * No significant case of high correlation among variables observed

# %%
sns.pairplot(data, hue="Class")
plt.show()

# %% [markdown]
# * Pregnancy and Age have a linear relation.
# * Age and Blood Pressure have little relation. Most of the aged people have Blood pressure.
# * Insulin and Glucose have some relation.
# * The distribution plots on diagonals for Class 0 and 1 seems to overlap a little.

# %% [markdown]
# ### Let's look at the distribution of target variable

# %%
data["Class"].value_counts()
# Out:
# 0    500
# 1    268
# Name: Class, dtype: int64

# %%
data["Class"].value_counts(1)
# Out:
# 0    0.651042
# 1    0.348958
# Name: Class, dtype: float64

# %% [markdown]
# * The number of observations where the person is non-diabetic are 500 which is 65% of the total data available.

# %% [markdown]
# ### Splitting data into train and test

# %%
X = data.drop(["Class"], axis=1)
Y = data["Class"]

# adding a contstant to X variable
X = add_constant(X)

# creating dummies
X = pd.get_dummies(X, drop_first=True)


# Splitting data in train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.30, random_state=1, stratify=Y
)

# %% [markdown]
# **The Stratify argument maintains the original distribution of classes in the target variable while splitting the data into train and test sets.**

# %% [markdown]
# ### Fitting Logistic Regression model

# %%
# fitting the model on training set
logit = sm.Logit(y_train, X_train.astype(float))
lg = logit.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.449508
#          Iterations 6

# %%
# let's print the logistic regression summary
print(lg.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  Class   No. Observations:                  537
# Model:                          Logit   Df Residuals:                      528
# Method:                           MLE   Df Model:                            8
# Date:                Thu, 02 Feb 2023   Pseudo R-squ.:                  0.3045
# Time:                        06:44:26   Log-Likelihood:                -241.39
# converged:                       True   LL-Null:                       -347.09
# Covariance Type:            nonrobust   LLR p-value:                 2.518e-41
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -9.7226      1.021     -9.522      0.000     -11.724      -7.721
# Pregnancies       0.1445      0.039      3.706      0.000       0.068       0.221
# Glucose           0.0363      0.005      7.819      0.000       0.027       0.045
# BloodPressure    -0.0038      0.010     -0.359      0.720      -0.024       0.017
# SkinThickness     0.0008      0.016      0.048      0.962      -0.031       0.032
# Insulin           0.0010      0.002      0.644      0.519      -0.002       0.004
# BMI               0.0936      0.022      4.186      0.000       0.050       0.137
# Pedigree          1.0345      0.351      2.950      0.003       0.347       1.722
# Age               0.0122      0.011      1.070      0.284      -0.010       0.035
# =================================================================================

# %% [markdown]
# * The coefficients of the logistic regression model are in terms of log(odd).
# * `P>|z|`: The interpretation of p-values is similar to that in Linear Regression.

# %% [markdown]
# ### Checking model performance

# %%
# predicting on training set
# default threshold is 0.5, if predicted probability is greater than 0.5 the observation will be classified as 1

pred_train = lg.predict(X_train) > 0.5
pred_train = np.round(pred_train)

# %% [markdown]
# #### Lets see the confusion matrix on training set

# %%
cm = confusion_matrix(y_train, pred_train)
plt.figure(figsize=(7, 5))
sns.heatmap(cm, annot=True, fmt="g")
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.show()

# %% [markdown]
# #### The confusion matrix
#
# * True Positives (TP):  A person has diabetes and the model predicted person has diabetes.
# * True Negatives (TN): A person doesn't have diabetes and the model predicted person doesn't have diabetes.
# * False Positives (FP): The model predicted person has diabetes but the person doesn't have diabetes.
# * False Negatives (FN): The model predicted person doesn't have diabetes but the person has diabetes.

# %% [markdown]
# #### Lets check the accuracy model

# %%
print("Accuracy on training set : ", accuracy_score(y_train, pred_train))
# Out:
# Accuracy on training set :  0.7858472998137802

# %% [markdown]
# * The model seems to be performing well on the training set.

# %% [markdown]
# #### But to make interpretations from the model, first we will have to remove multicollinearity from the data to get reliable coefficients and p-values.
# * There are different ways of detecting (or testing) multi-collinearity, one such way is the Variation Inflation Factor.

# %% [markdown]
# ### Checking for Multicollinearity

# %%
# let's check the VIF of the predictors
vif_series = pd.Series(
    [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])],
    index=X_train.columns,
    dtype=float,
)
print("VIF values: \n\n{}\n".format(vif_series))
# Out:
# VIF values:
#
# const            55.156267
# Pregnancies       1.418041
# Glucose           1.358583
# BloodPressure     1.226593
# SkinThickness     1.446856
# Insulin           1.227806
# BMI               1.546783
# Pedigree          1.054447
# Age               1.637294
# dtype: float64

# %% [markdown]
# * We observe that there is no multicollinearity present in the data.
# * Hence, The values of coefficient and p-values are reliable.
# * Let's remove the insignificant variables (p-value > 0.05) from data.

# %% [markdown]
# ### Removing insignificant variables (p-value > 0.05 )

# %%
# summary of initial logistic regression model
print(lg.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  Class   No. Observations:                  537
# Model:                          Logit   Df Residuals:                      528
# Method:                           MLE   Df Model:                            8
# Date:                Thu, 02 Feb 2023   Pseudo R-squ.:                  0.3045
# Time:                        06:44:27   Log-Likelihood:                -241.39
# converged:                       True   LL-Null:                       -347.09
# Covariance Type:            nonrobust   LLR p-value:                 2.518e-41
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -9.7226      1.021     -9.522      0.000     -11.724      -7.721
# Pregnancies       0.1445      0.039      3.706      0.000       0.068       0.221
# Glucose           0.0363      0.005      7.819      0.000       0.027       0.045
# BloodPressure    -0.0038      0.010     -0.359      0.720      -0.024       0.017
# SkinThickness     0.0008      0.016      0.048      0.962      -0.031       0.032
# Insulin           0.0010      0.002      0.644      0.519      -0.002       0.004
# BMI               0.0936      0.022      4.186      0.000       0.050       0.137
# Pedigree          1.0345      0.351      2.950      0.003       0.347       1.722
# Age               0.0122      0.011      1.070      0.284      -0.010       0.035
# =================================================================================

# %% [markdown]
# **Dropping SkinThickness as it has the highest p-value**

# %%
X_train1 = X_train.drop("SkinThickness", axis=1)

# %%
# fitting the model on training set
logit1 = sm.Logit(y_train, X_train1.astype(float))
lg1 = logit1.fit()

pred_train1 = lg1.predict(X_train1)
pred_train1 = np.round(pred_train1)


print("Accuracy on training set : ", accuracy_score(y_train, pred_train1))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.449511
#          Iterations 6
# Accuracy on training set :  0.7858472998137802

# %% [markdown]
# * There is no significant change in the model performance as compared to initial model.

# %%
# checking summary of the model
print(lg1.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  Class   No. Observations:                  537
# Model:                          Logit   Df Residuals:                      529
# Method:                           MLE   Df Model:                            7
# Date:                Thu, 02 Feb 2023   Pseudo R-squ.:                  0.3045
# Time:                        06:44:27   Log-Likelihood:                -241.39
# converged:                       True   LL-Null:                       -347.09
# Covariance Type:            nonrobust   LLR p-value:                 4.406e-42
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -9.7189      1.018     -9.548      0.000     -11.714      -7.724
# Pregnancies       0.1446      0.039      3.707      0.000       0.068       0.221
# Glucose           0.0363      0.005      7.820      0.000       0.027       0.045
# BloodPressure    -0.0038      0.010     -0.359      0.720      -0.024       0.017
# Insulin           0.0010      0.002      0.646      0.518      -0.002       0.004
# BMI               0.0942      0.020      4.811      0.000       0.056       0.133
# Pedigree          1.0348      0.351      2.952      0.003       0.348       1.722
# Age               0.0123      0.011      1.080      0.280      -0.010       0.035
# =================================================================================

# %% [markdown]
# **Dropping Blood Pressure with the highest p-value**

# %%
X_train2 = X_train1.drop("BloodPressure", axis=1)

# %%
# fitting the model on training set
logit2 = sm.Logit(y_train, X_train2.astype(float))
lg2 = logit2.fit()

pred_train2 = lg2.predict(X_train2)
pred_train2 = np.round(pred_train2)

print("Accuracy on training set : ", accuracy_score(y_train, pred_train2))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.449630
#          Iterations 6
# Accuracy on training set :  0.7839851024208566

# %% [markdown]
# * There is no significant change in the model performance as compared to initial model.

# %%
## checking summary of the model
print(lg2.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  Class   No. Observations:                  537
# Model:                          Logit   Df Residuals:                      530
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 02 Feb 2023   Pseudo R-squ.:                  0.3043
# Time:                        06:44:27   Log-Likelihood:                -241.45
# converged:                       True   LL-Null:                       -347.09
# Covariance Type:            nonrobust   LLR p-value:                 7.548e-43
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -9.8778      0.919    -10.744      0.000     -11.680      -8.076
# Pregnancies     0.1442      0.039      3.702      0.000       0.068       0.220
# Glucose         0.0361      0.005      7.837      0.000       0.027       0.045
# Insulin         0.0010      0.002      0.671      0.502      -0.002       0.004
# BMI             0.0922      0.019      4.903      0.000       0.055       0.129
# Pedigree        1.0394      0.350      2.973      0.003       0.354       1.725
# Age             0.0112      0.011      1.024      0.306      -0.010       0.033
# ===============================================================================

# %% [markdown]
# **Dropping Insulin with highest p-value**

# %%
X_train3 = X_train2.drop("Insulin", axis=1)

# %%
# fitting the model on training set
logit3 = sm.Logit(y_train, X_train3.astype(float))
lg3 = logit3.fit()

pred_train3 = lg3.predict(X_train3)
pred_train3 = np.round(pred_train3)

print("Accuracy on training set : ", accuracy_score(y_train, pred_train3))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.450056
#          Iterations 6
# Accuracy on training set :  0.7858472998137802

# %% [markdown]
# * There is no significant change in the model performance as compared to initial model.

# %%
## checking summary of the model
print(lg3.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  Class   No. Observations:                  537
# Model:                          Logit   Df Residuals:                      531
# Method:                           MLE   Df Model:                            5
# Date:                Thu, 02 Feb 2023   Pseudo R-squ.:                  0.3037
# Time:                        06:44:27   Log-Likelihood:                -241.68
# converged:                       True   LL-Null:                       -347.09
# Covariance Type:            nonrobust   LLR p-value:                 1.378e-43
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -9.8936      0.921    -10.746      0.000     -11.698      -8.089
# Pregnancies     0.1440      0.039      3.686      0.000       0.067       0.221
# Glucose         0.0372      0.004      8.584      0.000       0.029       0.046
# BMI             0.0937      0.019      5.005      0.000       0.057       0.130
# Pedigree        1.0388      0.349      2.972      0.003       0.354       1.724
# Age             0.0112      0.011      1.016      0.310      -0.010       0.033
# ===============================================================================

# %% [markdown]
# **Dropping Age with highest p-value**

# %%
X_train4 = X_train3.drop("Age", axis=1)

# %%
# fitting the model on training set
logit4 = sm.Logit(y_train, X_train4.astype(float))
lg4 = logit4.fit()

pred_train4 = lg4.predict(X_train4)
pred_train4 = np.round(pred_train4)

print("Accuracy on training set : ", accuracy_score(y_train, pred_train4))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.451011
#          Iterations 6
# Accuracy on training set :  0.7821229050279329

# %% [markdown]
# * There is no significant change in the model performance as compared to initial model.

# %%
## checking summary of the model
print(lg4.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  Class   No. Observations:                  537
# Model:                          Logit   Df Residuals:                      532
# Method:                           MLE   Df Model:                            4
# Date:                Thu, 02 Feb 2023   Pseudo R-squ.:                  0.3022
# Time:                        06:44:27   Log-Likelihood:                -242.19
# converged:                       True   LL-Null:                       -347.09
# Covariance Type:            nonrobust   LLR p-value:                 2.951e-44
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -9.6760      0.890    -10.873      0.000     -11.420      -7.932
# Pregnancies     0.1645      0.034      4.881      0.000       0.098       0.231
# Glucose         0.0381      0.004      8.943      0.000       0.030       0.046
# BMI             0.0927      0.019      4.955      0.000       0.056       0.129
# Pedigree        1.0442      0.349      2.996      0.003       0.361       1.727
# ===============================================================================

# %% [markdown]
# * Now all the columns left are significant predictors, let's check the model performance and make interpretations.

# %% [markdown]
# ### Coefficient interpretations
#
# * Coefficient of all the variables are positive. An increase in these will lead to increase in chances of a person having diabetes.

# %% [markdown]
# ###  Converting coefficients to odds
# * The coefficients of the logistic regression model are in terms of log(odd), to find the odds we have to take the exponential of the coefficients.
# * Therefore, **odds =  exp(b)**
# * The percentage change in odds is given as **odds = (exp(b) - 1) * 100**

# %% [markdown]
# **Odds from coefficients**

# %%
# converting coefficients to odds
odds = np.exp(lg4.params)

# adding the odds to a dataframe
pd.DataFrame(odds, X_train4.columns, columns=["odds"]).T
# Out:
#          const  Pregnancies   Glucose       BMI  Pedigree
# odds  0.000063     1.178781  1.038845  1.097174  2.841249

# %% [markdown]
# **Percentage change in odds**

# %%
# finding the percentage change
perc_change_odds = (np.exp(lg4.params) - 1) * 100

# adding the change_odds% to a dataframe
pd.DataFrame(perc_change_odds, X_train4.columns, columns=["change_odds%"]).T
# Out:
#                   const  Pregnancies   Glucose       BMI    Pedigree
# change_odds% -99.993723    17.878143  3.884519  9.717385  184.124936

# %% [markdown]
# ### Coefficient interpretations
#
# * `Pregnancies`: Holding all other features constant, a unit change in Pregnancy will increase the odds of a person having diabetes by 1.787 times or a 17.87% increase in the odds of having diabetes.
#
# * `Glucose`: Holding all other features constant, a unit change in Glucose will increase the odds of a person having diabetes by 1.03 times or a 3.88% increase in the odds of having diabetes.
#
# * `BMI`: Holding all other features constant, a unit change in BMI will increase the odds of a person having diabetes by 1.097 times or a 9.71% increase in the odds of having diabetes.
#
# * `Pedigree`: Holding all other features constant, a unit change in Pedigree will increase the odds of a person having diabetes by 2.84 times or a 184.12% increase in the odds of having diabetes.

# %% [markdown]
# ### Performance Metrics of the final model - 'lg4'

# %% [markdown]
# **Confusion Matrix on training set**

# %%
cm = confusion_matrix(y_train, pred_train4)
plt.figure(figsize=(7, 5))
sns.heatmap(cm, annot=True, fmt="g")
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.show()

# %% [markdown]
# **Accuracy on training set**

# %%
print("Accuracy on training set : ", accuracy_score(y_train, pred_train4))
# Out:
# Accuracy on training set :  0.7821229050279329

# %% [markdown]
# **ROC-AUC on training set**

# %%
logit_roc_auc_train = roc_auc_score(y_train, lg4.predict(X_train4))
fpr, tpr, thresholds = roc_curve(y_train, lg4.predict(X_train4))
plt.figure(figsize=(7, 5))
plt.plot(fpr, tpr, label="Logistic Regression (area = %0.2f)" % logit_roc_auc_train)
plt.plot([0, 1], [0, 1], "r--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# * Model is performing well on the training set.

# %% [markdown]
# ### We can now use the model for making predictions on the test data.

# %%
# dropping variables from test set as well which were dropped from training set
X_test = X_test.drop(["SkinThickness", "BloodPressure", "Insulin", "Age"], axis=1)

# %%
pred_test = lg4.predict(X_test) > 0.5
pred_test = np.round(pred_test)

# %%
print("Accuracy on training set : ", accuracy_score(y_train, pred_train4))
print("Accuracy on test set : ", accuracy_score(y_test, pred_test))
# Out:
# Accuracy on training set :  0.7821229050279329
# Accuracy on test set :  0.7489177489177489

# %% [markdown]
# * Logistic Regression has given a generalized performance on training and test set.
